# %% [markdown]
# # Profiler Results

# %%
import pstats
from pstats import SortKey

# %%
p = pstats.Stats("../profile01.txt")

# %%
# p.strip_dirs().sort_stats(SortKey.CUMULATIVE).print_stats()
p.sort_stats(SortKey.TIME).print_stats()
# Out:
# Wed Jan 24 14:52:37 2024    ../profile01.txt
#
#          12932093 function calls (12520438 primitive calls) in 20.664 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     81934    1.229    0.000    1.229    0.000 {method 'add' of 'torch._C._TensorBase' objects}
#     81534    1.227    0.000    1.227    0.000 {method 'mul_' of 'torch._C._TensorBase' objects}
#      5938    0.858    0.000    0.858    0.000 {method 'run_backward' of 'torch._C._EngineBase' objects}
#   210/208    0.822    0.004    0.825    0.004 {built-in method _imp.create_dynamic}
#    163468    0.821    0.000    0.821    0.000 {method 'add_' of 'torch._C._TensorBase' objects}
#     52256    0.552    0.000    0.552    0.000 {built-in method torch._ops.profiler._record_function_enter_new}
#         1    0.548    0.548   13.234   13.234 decentralized.py:123(decentralized_train_loop)
# ...

# %%
p_gmf = pstats.Stats("../profile_gmf")
p_gmf.strip_dirs().sort_stats(SortKey.TIME).print_stats()
# Out:
# Wed Jan 24 15:03:33 2024    ../profile_gmf
#
#          857716957 function calls (753953853 primitive calls) in 353.094 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#  68219367   73.001    0.000  214.409    0.000 module.py:2156(_named_members)
# 136613880/34241043   70.151    0.000   76.952    0.000 module.py:2335(named_modules)
#     29091   30.837    0.001  281.311    0.010 module.py:2443(zero_grad)
# 137230694   23.894    0.000   35.148    0.000 _tensor.py:1002(__hash__)
# 102878883   19.926    0.000   36.393    0.000 {method 'add' of 'set' objects}
#  68219367   19.153    0.000  251.312    0.000 module.py:2170(parameters)
#     35029   18.861    0.001   18.993    0.001 sgd.py:36(_init_group)
#  68219367   17.750    0.000  232.159    0.000 module.py:2195(named_parameters)
# 137276172   11.260    0.000   11.260    0.000 {built-in method builtins.id}
# ...

# %%
p_gmf02 = pstats.Stats("../profile_gmf02")
p_gmf02.strip_dirs().sort_stats(SortKey.TIME).print_stats()
# Out:
# Wed Jan 24 16:50:43 2024    ../profile_gmf02
#
#          48942351 function calls (47201383 primitive calls) in 81.501 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     35029   21.487    0.001   22.042    0.001 sgd.py:36(_init_group)
#    973448    5.956    0.000    5.956    0.000 {method 'mul_' of 'torch._C._TensorBase' objects}
#   1028854    4.404    0.000    4.404    0.000 {method 'add' of 'torch._C._TensorBase' objects}
#   2002302    4.167    0.000    4.167    0.000 {method 'add_' of 'torch._C._TensorBase' objects}
#      5938    3.524    0.001    3.701    0.001 optimizer.py:776(zero_grad)
#     35029    2.442    0.000   17.310    0.000 sgd.py:231(_single_tensor_sgd)
#    117204    2.384    0.000    2.525    0.000 module.py:451(__init__)
#   1791970    1.837    0.000    1.837    0.000 module.py:1682(__getattr__)
#    939004    1.654    0.000    4.543    0.000 module.py:1697(__setattr__)
# ...
