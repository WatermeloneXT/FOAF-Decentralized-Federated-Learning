# %%
from os import chdir
from pathlib import Path

cwd = Path.cwd()
print(f"CWD: {cwd}")
if cwd.name == "code":
    chdir("..")
print(f"CWD: {Path.cwd()}")
# Out:
# CWD: /Users/haowen/Documents/Decentral RS/fed-learning-main/code
# CWD: /Users/haowen/Documents/Decentral RS/fed-learning-main

# %%
from src.models.MatrixFactorization import MF, UMF
from src.graphs import random_k_out_graph, create_graph
from src.users import User
from src.training.decentralized import (decentralized_train_n_epochs,
                                        decentralized_validate_loop)
from src.data_utils import create_batched_dataloaders, create_dataloader

# %%
#Make data sample iterable
from torch.utils.data import Dataset, DataLoader, TensorDataset, Sampler
import torch
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.optim import SGD

from collections import Counter
import networkx as nx
from networkx.generators.classic import empty_graph
from networkx.utils import discrete_sequence, py_random_state, weighted_choice

import seaborn as sns
from sklearn.utils import shuffle

# %% [markdown]
# ## Parameter Setting

# %%
model = "umf"
val_loader_type = "rs"
train_loader_type = "rs"
userprop = None
n_factors = 30
sparse = False
batch_size = 10
lr = 0.03871364416669273
weight_decay = 0.14214480688557163
mom = 0.001
graph_seed = 1
n_epochs = 50

# %% [markdown]
# ## Main

# %%
train_df = pd.read_csv("dataset/ml100k_train.csv")
test_df = pd.read_csv("dataset/ml100k_test.csv")
train_df.head()
# Out:
#    user_id  item_id  rating  rating.1
# 0      207       87       5         5
# 1      675      900       4         4
# 2      373      230       2         2
# 3      377      564       3         3
# 4      725      843       3         3

# %%
n_users = train_df['user_id'].nunique()
n_items = train_df['item_id'].nunique()
print(f"Total User: {n_users}")
print(f"Total Item: {n_items}")
# Out:
# Total User: 943
# Total Item: 1628

# %%
train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=0)
train_data_loader = create_dataloader(
        df=train_df, dl_type=train_loader_type, batch_size=batch_size, p=userprop
    )
val_data_loader = create_dataloader(df=val_df, dl_type=val_loader_type)
test_data_loader = create_dataloader(df=test_df, dl_type=val_loader_type)

# %%
users = {}
for i in tqdm(range(n_users)):
    # model = MF(n_users=n_users, n_items=n_items)
    user_model = UMF(n_items, n_factors = n_factors, sparse = sparse)
    # model = GeneralizedMFOneLayer(n_users=n_users, n_items=n_items)
    #users[i] = User(id=i, model=user_model, optimizer=SGD(user_model.parameters(), lr=lr, weight_decay=weight_decay), model_name = model)
    users[i] = User(
            id=i,
            model=user_model,
            optimizer=SGD(user_model.parameters(), lr=lr, weight_decay=weight_decay, momentum=mom),
            model_name=model,
        )
# Out:
#   0%|          | 0/943 [00:00<?, ?it/s]

# %%
graph = random_k_out_graph(n=n_users, k=2, seed=graph_seed)

# %%
import torch
torch.manual_seed(0)
train_losses, val_losses, time_per_epoch, commutes = decentralized_train_n_epochs(
        user_models=users,
        train_loader=train_data_loader,
        val_loader=val_data_loader,
        epochs=n_epochs,
        graph=graph,
    )
# Out:
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 1 | Train Loss: 0.6354 | Validation Loss: 1.9543 | Time Elapsed: 78.204671 sec |Commute: 119802 |
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 2 | Train Loss: 0.2313 | Validation Loss: 1.9186 | Time Elapsed: 78.907961 sec |Commute: 119802 |
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 3 | Train Loss: 0.1536 | Validation Loss: 1.8572 | Time Elapsed: 82.747174 sec |Commute: 119802 |
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 4 | Train Loss: 0.0999 | Validation Loss: 1.8015 | Time Elapsed: 79.459355 sec |Commute: 119802 |
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 5 | Train Loss: 0.0655 | Validation Loss: 1.7335 | Time Elapsed: 73.507921 sec |Commute: 119802 |
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 6 | Train Loss: 0.0446 | Validation Loss: 1.6743 | Time Elapsed: 74.336517 sec |Commute: 119802 |
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 7 | Train Loss: 0.0328 | Validation Loss: 1.6438 | Time Elapsed: 73.326872 sec |Commute: 119802 |
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 8 | Train Loss: 0.0267 | Validation Loss: 1.5551 | Time Elapsed: 73.749104 sec |Commute: 119802 |
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 9 | Train Loss: 0.0234 | Validation Loss: 1.5043 | Time Elapsed: 77.281769 sec |Commute: 119802 |
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 10 | Train Loss: 0.0215 | Validation Loss: 1.4723 | Time Elapsed: 64.823053 sec |Commute: 119802 |
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 11 | Train Loss: 0.0206 | Validation Loss: 1.4242 | Time Elapsed: 46.769914 sec |Commute: 119802 |
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 12 | Train Loss: 0.0200 | Validation Loss: 1.3814 | Time Elapsed: 54.736062 sec |Commute: 119802 |
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 13 | Train Loss: 0.0195 | Validation Loss: 1.3650 | Time Elapsed: 77.417190 sec |Commute: 119802 |
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 14 | Train Loss: 0.0193 | Validation Loss: 1.3226 | Time Elapsed: 93.591268 sec |Commute: 119802 |
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 15 | Train Loss: 0.0191 | Validation Loss: 1.2941 | Time Elapsed: 104.896696 sec |Commute: 119802 |
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 16 | Train Loss: 0.0190 | Validation Loss: 1.2756 | Time Elapsed: 102.849865 sec |Commute: 119802 |
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 17 | Train Loss: 0.0188 | Validation Loss: 1.2467 | Time Elapsed: 101.783956 sec |Commute: 119802 |
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 18 | Train Loss: 0.0187 | Validation Loss: 1.2292 | Time Elapsed: 103.004249 sec |Commute: 119802 |
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 19 | Train Loss: 0.0187 | Validation Loss: 1.2031 | Time Elapsed: 102.683471 sec |Commute: 119802 |
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 20 | Train Loss: 0.0186 | Validation Loss: 1.1864 | Time Elapsed: 100.097888 sec |Commute: 119802 |
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 21 | Train Loss: 0.0185 | Validation Loss: 1.1693 | Time Elapsed: 111.197150 sec |Commute: 119802 |
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 22 | Train Loss: 0.0185 | Validation Loss: 1.1617 | Time Elapsed: 89.847432 sec |Commute: 119802 |
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 23 | Train Loss: 0.0184 | Validation Loss: 1.1327 | Time Elapsed: 74.686770 sec |Commute: 119802 |
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 24 | Train Loss: 0.0183 | Validation Loss: 1.1277 | Time Elapsed: 75.325729 sec |Commute: 119802 |
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 25 | Train Loss: 0.0183 | Validation Loss: 1.1303 | Time Elapsed: 74.774475 sec |Commute: 119802 |
# Early stopping.
# Total time elapsed: 2073.131196833041

# %%
test_loss = decentralized_validate_loop(users, test_data_loader)

# %%
test_loss
# Out:
# 1.1079909

# %%
sum(commutes)
# Out:
# 2995050
