# %%
from os import chdir
from pathlib import Path
from tqdm import tqdm
cwd = Path.cwd()
print(f"CWD: {cwd}")
if cwd.name == "code":
    chdir("..")
print(f"CWD: {Path.cwd()}")
# Out:
# CWD: /Users/haowen/Documents/Decentral RS/fed-learning-main
# CWD: /Users/haowen/Documents/Decentral RS/fed-learning-main

# %%
from src.models.MatrixFactorization import MF, UMF
from src.graphs import random_k_out_graph, create_graph, create_cycle_graph
from src.users import User
from src.training.decentralized import decentralized_validate_loop, decentralized_train_n_epochs
from src.data_utils import create_batched_dataloaders, create_dataloader
from networkx import Graph
from tqdm.auto import tqdm

# %%
#Make data sample iterable
from torch.utils.data import Dataset, DataLoader, TensorDataset, Sampler
import torch
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.optim import SGD

from collections import Counter
import networkx as nx
from networkx.generators.classic import empty_graph
from networkx.utils import discrete_sequence, py_random_state, weighted_choice

import seaborn as sns

# %%
def share_gradient(user, users, graph, item_id=None):

    commute = 0 
    user_neighbors = graph.adj[user.id]
    # user_gradients = {
    #     name: param.grad for name, param in user.model.named_parameters() if "item" in name
    # }
    item_parameter_names = ["item_factors.weight", "item_bias.weight"]
    if user.model_name == "gmf":
        item_parameter_names.append(f"item_layer_dict.item{item_id}.weight")
        item_parameter_names.append(f"item_layer_dict.item{item_id}.bias")
    elif user.model_name == "gmf_shared":
        item_parameter_names.append("item_layers.weight")
        item_parameter_names.append("item_layers.bias")

    user_gradients = {name: user.model.get_parameter(name).grad for name in item_parameter_names}
    # print(f"Number of elements being shared: {sum([g.numel() for _, g in user_gradients.items()])}")

    for neighbor_id in user_neighbors:
        neighbor = users[neighbor_id]
        neighbor_model = neighbor.model
        neighbor_optimizer = neighbor.optimizer
        neighbor_model.zero_grad() # required - diverges without this line
        commute = commute + 1
        for name in item_parameter_names:
            param = neighbor_model.get_parameter(name)
            param.grad = user_gradients[name].clone()
            
        # for name, param in neighbor_model.named_parameters():
        #     # print(name)
        #     if "item" in name:
        #         param.grad = user_gradients[name]  # Assign gradients to the neighbors
        neighbor_optimizer.step()  # Neighbors' update

    return commute

# %%
def decentralized_train_loop(user_models, train_loader, graph, progress_bar=True):
    loss_fn = nn.MSELoss(reduction="mean")
    for _, user in user_models.items():
        user.model.train()
    losses = np.empty(len(train_loader))
    total_n_obs = 0
    total_sum_loss = 0
    avg_loss = 0
    total_commute = 0
    tbar = tqdm(train_loader) if progress_bar else train_loader
    for idx, (inputs, target) in enumerate(tbar):
        if inputs.ndim == 3:
            inputs = inputs.squeeze(0)
            target = target.squeeze(0)
        n_obs = inputs.shape[0]
        user_id = int(inputs[0, 0])
        user = user_models[user_id]
        optimizer = user.optimizer
        optimizer.zero_grad()
        score = user.model(inputs[:, 0], inputs[:, 1])
        loss = loss_fn(score, target.float())
        loss.backward()  # Calculate Gradients

        if inputs[:,1].numel() == 1:
            commute = share_gradient(user, user_models, graph, item_id=inputs[:,1].item())
        else:
            commute = share_gradient(user, user_models, graph)
        optimizer.step()  # Current user's update
        
        total_commute += commute
        # print(f"Number of elements being shared: {sum([g.numel() for _, g in user_gradients.items()])}")
        total_n_obs += n_obs
        total_sum_loss += loss.detach().numpy() * n_obs
        losses[idx] = loss.detach().numpy()
        # loss_list.append(loss.detach().cpu().item())
        # avg_loss = losses[:idx + 1].mean()
        # avg_loss = total_sum_loss / total_n_obs
        avg_loss = avg_loss * (idx / (idx + 1)) + loss.detach().numpy() / (idx + 1) / n_obs
        if idx % 1000 == 0:
            if progress_bar:
                tbar.set_description(
                    f"Average Training Loss: {np.sqrt(avg_loss):.04f} | Loss: {loss.detach():.04f}"
                )
            if np.isnan(avg_loss):
                raise ValueError
    return avg_loss, total_commute
    # return avg_loss, total_commute

# %%
def decentralized_train_n_epochs(user_models, train_loader, val_loader, epochs: int, graph: Graph):
    start_time = perf_counter()
    train_losses = []
    train_commutes = []
    val_losses = []
    val_loss = decentralized_validate_loop(user_models, val_loader)
    mlflow.log_metrics({"Validation RMSE": val_loss}, step=0)
    val_losses.append(val_loss)
    time_per_epoch = []

    early_stopper = EarlyStopper(patience=1, min_rel_delta=0.0001)
    for epoch in range(epochs):
        start = perf_counter()
        avg_loss, train_commute = decentralized_train_loop(
            user_models=user_models, train_loader=train_loader, graph=graph
        )

        train_losses.append(avg_loss)
        train_commutes.append(train_commute)
        val_loss = decentralized_validate_loop(user_models, val_loader)
        val_losses.append(val_loss)


        time_elapsed = perf_counter() - start
        time_per_epoch.append(time_elapsed)
        log_text = (
            f"Epoch {epoch + 1} | "
            f"Train Loss: {np.sqrt(avg_loss):.04f} | "
            f"Validation Loss: {val_loss:.04f} | "
            f"Time Elapsed: {time_elapsed:03f} sec |"
            f"Commute: {train_commute} | "
        )
        print(log_text)
        mlflow.log_metrics(
            {
                "Train RMSE": avg_loss,
                "Train Commute": train_commute,
                "Validation RMSE": val_loss,
                "epochs_started": epoch+1,
            },
            step=epoch + 1,
        )
        if early_stopper.early_stop(val_loss):
            print("Early stopping.")
            break
    total_time = perf_counter() - start_time
    print(f"Total time elapsed: {total_time}")
    return train_losses, val_losses, time_per_epoch, train_commutes

# %%
model = "umf"
val_loader_type = "rs"
userprop = 0.6
n_factors = 30
sparse = False
batch_size = 10
#lr = 0.03871364416669273
#weight_decay = 0.14214480688557163
graph_seed = 1
n_epochs = 50

para_vec= {
  "scalefree_userprop" : [0.006721468985407216, 0.3793755748581348, 0.7023494584199832],
  "scalefree_urs" : [0.00797255113179729, 0.7291631699209506, 0.7649689575684868],
  "scalefree_rs" : [0.043245636749499355, 0.24293301237845355, 0.6590721600407826],
  "scalefree_oaat" : [0.014505446034196021, 0.1281494707675557, 0.3063931184178566],
    
  "cycle_userprop" : [0.03448020025507248, 0.1530360406099725, 0.3265046312442892],
  "cycle_urs" : [0.015085184891905544, 0.32597756888723617, 0.9165691479123227],
  "cycle_rs" : [0.04518354114581989, 0.07432773840871296, 0.5104116722654509],
  "cycle_oaat" : [0.006051947990064438, 0.407449910177748, 0.6941867781038726],
    
  "random2_userprop" : [0.05973335259492166, 0.20270185084925238, 0.7097401156875496],
  "random2_urs" : [0.03871364416669273, 0.14214480688557163, 0.4403378739685112],
  "random2_rs" : [0.0341364110655981, 0.006786098078128074, 0.4848527175520783],
  "random2_oaat" : [0.012098247288774554, 0.051267232285266244, 0.5034632200402083],

  "random5_userprop" : [0.01214468819649195, 0.16071055871166323, 0.8930612583507401],
  "random5_urs" : [0.04664261576162963, 0.2261414992421005, 0.3645222958218734],
  "random5_rs" : [0.01864856189846265, 0.07043500222618476, 0.850748837624225],
  "random5_oaat" : [0.004358629931177893, 0.27784542450084454, 0.41295161556157467]
    
}

# %%
search_space = ["cycle_userprop", "cycle_urs", "cycle_rs", "cycle_oaat"]
model = "umf"
val_loader_type = "rs"
userprop = 0.6
n_factors = 30
sparse = False
batch_size = 10
graph_seed = 1
n_epochs = 50
test_vec = []
commute_vec = []
gtypes, dl_types = map(list, zip(*map(lambda x:x.split('_'), search_space)))

# %%
for i in np.arange(len(dl_types)):
    train_loader_type = dl_types[i]
    graph_type = "cycle"#gtypes[i]
    print(train_loader_type)
    temp_para = para_vec[search_space[i]]
    lr = temp_para[0]
    weight_decay = temp_para[1]
    mom = temp_para[2]
    print(f"lr : {lr} | wd : {weight_decay} | mom : {mom}")
     
    train_df = pd.read_csv("dataset/ml100k_train.csv")
    test_df = pd.read_csv("dataset/ml100k_test.csv")
    n_users = train_df['user_id'].nunique()
    n_items = train_df['item_id'].nunique() 

    train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=0)
    train_data_loader = create_dataloader(
        df=train_df, dl_type=train_loader_type, batch_size=batch_size, p=0.6
        )
    val_data_loader = create_dataloader(df=val_df, dl_type=val_loader_type)
    test_data_loader = create_dataloader(df=test_df, dl_type=val_loader_type)

    users = {}
    for i in tqdm(range(n_users)):
        # model = MF(n_users=n_users, n_items=n_items)
        user_model = UMF(n_items, n_factors = n_factors, sparse = sparse)
        # model = GeneralizedMFOneLayer(n_users=n_users, n_items=n_items)
        users[i] = User(id=i, model=user_model, optimizer=SGD(user_model.parameters(), lr=lr, weight_decay=weight_decay,momentum=mom), model_name = model)
    
    graph = create_cycle_graph(n_users)
    
    train_losses, val_losses, time_per_epoch, commutes = decentralized_train_n_epochs(
        user_models=users,
        train_loader=train_data_loader,
        val_loader=val_data_loader,
        epochs=n_epochs,
        graph=graph,
        )  
    test_loss = decentralized_validate_loop(users, test_data_loader)
    test_vec = np.append(test_vec, test_loss)
    commute_vec = np.append(commute_vec, sum(commutes))

# %%
train_df = pd.read_csv("dataset/ml100k_train.csv")
test_df = pd.read_csv("dataset/ml100k_test.csv")
n_users = train_df['user_id'].nunique()
n_items = train_df['item_id'].nunique() 

train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=0)
train_data_loader = create_dataloader(
    df=train_df, dl_type= "rs", batch_size=batch_size, p=0.6
    )

# %%
train_data_loader

# %%
tbar = tqdm(train_loader) if progress_bar else train_loader
for idx, (inputs, target) in enumerate(tbar):
    print(idx)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 tbar = tqdm(train_loader) if progress_bar else train_loader
#       2 for idx, (inputs, target) in enumerate(tbar):
#       3     print(idx)
#
# NameError: name 'progress_bar' is not defined

# %%
from torch.utils.data import DataLoader, TensorDataset
import torch
from tqdm import tqdm

# Dummy data
X = torch.randn(1000, 10)
y = torch.randint(0, 2, (1000,))
dataset = TensorDataset(X, y)
train_loader = DataLoader(dataset, batch_size=32, shuffle=True)

# Toggle this to True or False
progress_bar = True

tbar = tqdm(train_loader) if progress_bar else train_loader
a = 0
for idx, (inputs, target) in enumerate(tbar):
  print(inputs.shape[0])
# Out:
# 100%|█████████████████████████████████████████| 32/32 [00:00<00:00, 4408.39it/s]
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 8

# %%
i = 2
train_loader_type = dl_types[i]
train_loader_type
# Out:
# 'rs'

# %%
i = 2
train_loader_type = dl_types[i]
graph_type = "random_2_out"#gtypes[i]
print(train_loader_type)
temp_para = para_vec[search_space[i]]
lr = temp_para[0]
weight_decay = temp_para[1]
mom = temp_para[2]
print(f"lr : {lr} | wd : {weight_decay} | mom : {mom}")
 
train_df = pd.read_csv("dataset/ml100k_train.csv")
test_df = pd.read_csv("dataset/ml100k_test.csv")
n_users = train_df['user_id'].nunique()
n_items = train_df['item_id'].nunique() 

train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=0)
train_data_loader = create_dataloader(
    df=train_df, dl_type=train_loader_type, batch_size=batch_size, p=0.6
    )
val_data_loader = create_dataloader(df=val_df, dl_type=val_loader_type)
test_data_loader = create_dataloader(df=test_df, dl_type=val_loader_type)

users = {}
for i in tqdm(range(n_users)):
    # model = MF(n_users=n_users, n_items=n_items)
    user_model = UMF(n_items, n_factors = n_factors, sparse = sparse)
    # model = GeneralizedMFOneLayer(n_users=n_users, n_items=n_items)
    users[i] = User(id=i, model=user_model, optimizer=SGD(user_model.parameters(), lr=lr, weight_decay=weight_decay,momentum=mom), model_name = model)

graph = create_graph(graph_type=graph_type, n_users=n_users, seed=1, order=1)
# Out:
# rs
# lr : 0.04518354114581989 | wd : 0.07432773840871296 | mom : 0.5104116722654509
#   0%|          | 0/943 [00:00<?, ?it/s]

# %%
train_losses, val_losses, time_per_epoch, commutes = decentralized_train_n_epochs(
        user_models=users,
        train_loader=train_data_loader,
        val_loader=val_data_loader,
        epochs=n_epochs,
        graph=graph,
        )
# Out:
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 1 | Train Loss: 1.8509 | Validation Loss: 4.6070 | Time Elapsed: 3.030430 sec |Commute: 1885 | Commute Cost:
# 47591324
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 2 | Train Loss: 1.5285 | Validation Loss: 4.0651 | Time Elapsed: 3.387443 sec |Commute: 1885 | Commute Cost:
# 47591324
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 3 | Train Loss: 1.2832 | Validation Loss: 3.5466 | Time Elapsed: 3.011570 sec |Commute: 1885 | Commute Cost:
# 47591324
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 4 | Train Loss: 1.0986 | Validation Loss: 3.0336 | Time Elapsed: 3.228063 sec |Commute: 1885 | Commute Cost:
# 47591324
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 5 | Train Loss: 1.0173 | Validation Loss: 2.6176 | Time Elapsed: 2.901586 sec |Commute: 1885 | Commute Cost:
# 47591324
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 6 | Train Loss: 0.9076 | Validation Loss: 2.2520 | Time Elapsed: 3.241404 sec |Commute: 1885 | Commute Cost:
# 47591324
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 7 | Train Loss: 0.7808 | Validation Loss: 1.9530 | Time Elapsed: 3.202332 sec |Commute: 1885 | Commute Cost:
# 47591324
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 8 | Train Loss: 0.7009 | Validation Loss: 1.6974 | Time Elapsed: 2.831146 sec |Commute: 1885 | Commute Cost:
# 47591324
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 9 | Train Loss: 0.6336 | Validation Loss: 1.5334 | Time Elapsed: 2.815380 sec |Commute: 1885 | Commute Cost:
# 47591324
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 10 | Train Loss: 0.5827 | Validation Loss: 1.4084 | Time Elapsed: 2.898782 sec |Commute: 1885 | Commute Cost:
# 47591324
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 11 | Train Loss: 0.5358 | Validation Loss: 1.3151 | Time Elapsed: 2.894965 sec |Commute: 1885 | Commute Cost:
# 47591324
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 12 | Train Loss: 0.5034 | Validation Loss: 1.2757 | Time Elapsed: 2.770122 sec |Commute: 1885 | Commute Cost:
# 47591324
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 13 | Train Loss: 0.4905 | Validation Loss: 1.2500 | Time Elapsed: 2.934868 sec |Commute: 1885 | Commute Cost:
# 47591324
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 14 | Train Loss: 0.4930 | Validation Loss: 1.2162 | Time Elapsed: 2.973955 sec |Commute: 1885 | Commute Cost:
# 47591324
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 15 | Train Loss: 0.4620 | Validation Loss: 1.1897 | Time Elapsed: 2.979367 sec |Commute: 1885 | Commute Cost:
# 47591324
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 16 | Train Loss: 0.4401 | Validation Loss: 1.1479 | Time Elapsed: 2.906607 sec |Commute: 1885 | Commute Cost:
# 47591324
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 17 | Train Loss: 0.4214 | Validation Loss: 1.1350 | Time Elapsed: 3.066468 sec |Commute: 1885 | Commute Cost:
# 47591324
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 18 | Train Loss: 0.4126 | Validation Loss: 1.0816 | Time Elapsed: 3.110716 sec |Commute: 1885 | Commute Cost:
# 47591324
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 19 | Train Loss: 0.3931 | Validation Loss: 1.0499 | Time Elapsed: 2.702250 sec |Commute: 1885 | Commute Cost:
# 47591324
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 20 | Train Loss: 0.3707 | Validation Loss: 1.0140 | Time Elapsed: 2.746792 sec |Commute: 1885 | Commute Cost:
# 47591324
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 21 | Train Loss: 0.3543 | Validation Loss: 0.9834 | Time Elapsed: 2.955377 sec |Commute: 1885 | Commute Cost:
# 47591324
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 22 | Train Loss: 0.3319 | Validation Loss: 0.9690 | Time Elapsed: 2.995328 sec |Commute: 1885 | Commute Cost:
# 47591324
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 23 | Train Loss: 0.3188 | Validation Loss: 0.9457 | Time Elapsed: 3.492313 sec |Commute: 1885 | Commute Cost:
# 47591324
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 24 | Train Loss: 0.3048 | Validation Loss: 0.9515 | Time Elapsed: 3.068710 sec |Commute: 1885 | Commute Cost:
# 47591324
#   0%|          | 0/943 [00:00<?, ?it/s]
# Epoch 25 | Train Loss: 0.2960 | Validation Loss: 0.9592 | Time Elapsed: 3.078108 sec |Commute: 1885 | Commute Cost:
# 47591324
# Early stopping.
# Total time elapsed: 77.78018033300759

# %%
i=1
train_loader_type = "urs"
graph_type = "random_2_out"#gtypes[i]
print(train_loader_type)
temp_para = para_vec[search_space[i]]
lr = temp_para[0]
weight_decay = temp_para[1]
mom = temp_para[2]
print(f"lr : {lr} | wd : {weight_decay} | mom : {mom}")
 
train_df = pd.read_csv("dataset/ml100k_train.csv")
test_df = pd.read_csv("dataset/ml100k_test.csv")
n_users = train_df['user_id'].nunique()
n_items = train_df['item_id'].nunique() 

train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=0)
train_data_loader = create_dataloader(
    df=train_df, dl_type=train_loader_type, batch_size=batch_size, p=0.6
    )
val_data_loader = create_dataloader(df=val_df, dl_type=val_loader_type)
test_data_loader = create_dataloader(df=test_df, dl_type=val_loader_type)

users = {}
for i in tqdm(range(n_users)):
    # model = MF(n_users=n_users, n_items=n_items)
    user_model = UMF(n_items, n_factors = n_factors, sparse = sparse)
    # model = GeneralizedMFOneLayer(n_users=n_users, n_items=n_items)
    users[i] = User(id=i, model=user_model, optimizer=SGD(user_model.parameters(), lr=lr, weight_decay=weight_decay,momentum=mom), model_name = model)

graph = create_graph(graph_type=graph_type, n_users=n_users, seed=1, order=1)
# Out:
# urs
# lr : 0.015085184891905544 | wd : 0.32597756888723617 | mom : 0.9165691479123227
#   0%|          | 0/943 [00:00<?, ?it/s]

# %%
loss_fn = nn.MSELoss(reduction="mean")
for _, user in users.items():
    user.model.train()
losses = np.empty(len(train_data_loader))
total_n_obs = 0
total_sum_loss = 0
avg_loss = 0
total_commute = 0
tbar = tqdm(train_data_loader) #if progress_bar else train_loader
for idx, (inputs, target) in enumerate(tbar):
        if inputs.ndim == 3:
            inputs = inputs.squeeze(0)
            target = target.squeeze(0)
        n_obs = inputs.shape[0]
        user_id = int(inputs[0, 0])
        user = users[user_id]
        optimizer = user.optimizer
        optimizer.zero_grad()
        score = user.model(inputs[:, 0], inputs[:, 1])
        loss = loss_fn(score, target.float())
        loss.backward()  # Calculate Gradients

        if inputs[:,1].numel() == 1:
            commute = share_gradient(user, users, graph, item_id=inputs[:,1].item())
        else:
            commute = share_gradient(user, users, graph)
        optimizer.step()  # Current user's update
        
        total_commute += commute
        total_n_obs += 1
# Out:
#   0%|          | 0/943 [00:00<?, ?it/s]

# %%
train_df.shape
# Out:
# (60000, 4)

# %%
n_users
# Out:
# 943

# %%
train_data_loader = create_dataloader(
    df=train_df, dl_type="urs", batch_size=batch_size, p=0.6
    )

# %%
X, y = train_df.iloc[:, :2].to_numpy(), train_df.iloc[:, 2].to_numpy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[210], line 1
# ----> 1 X, y = df.iloc[:, :2].to_numpy(), df.iloc[:, 2].to_numpy()
#
# NameError: name 'df' is not defined

# %%
commute = 0 
user_neighbors = graph.adj[user.id]
# user_gradients = {
#     name: param.grad for name, param in user.model.named_parameters() if "item" in name
# }
item_parameter_names = ["item_factors.weight", "item_bias.weight"]
if user.model_name == "gmf":
    item_parameter_names.append(f"item_layer_dict.item{item_id}.weight")
    item_parameter_names.append(f"item_layer_dict.item{item_id}.bias")
elif user.model_name == "gmf_shared":
    item_parameter_names.append("item_layers.weight")
    item_parameter_names.append("item_layers.bias")

user_gradients = {name: user.model.get_parameter(name).grad for name in item_parameter_names}
# print(f"Number of elements being shared: {sum([g.numel() for _, g in user_gradients.items()])}")

for neighbor_id in user_neighbors:
    neighbor = users[neighbor_id]
    neighbor_model = neighbor.model
    neighbor_optimizer = neighbor.optimizer
    neighbor_model.zero_grad() # required - diverges without this line
    commute = commute + 1
    for name in item_parameter_names:
        param = neighbor_model.get_parameter(name)
        param.grad = user_gradients[name].clone()
        
    # for name, param in neighbor_model.named_parameters():
    #     # print(name)
    #     if "item" in name:
    #         param.grad = user_gradients[name]  # Assign gradients to the neighbors
    neighbor_optimizer.step()  # Neighbors' update

# %%
commute
# Out:
# 2

# %%
class UserStratifiedDataset(Dataset):
    """Randomly select data from a given user."""

    def __init__(self, x: np.ndarray, y: np.ndarray, batch_size: int | None = None):
        self.x = torch.tensor(x)
        self.y = torch.tensor(y).unsqueeze(-1)
        self.batch_size = batch_size

    def __len__(self):
        # return 
        return len(self.x[:, 0].unique())

    def __getitem__(self, user):
        user_idx = self.x[:, 0] == user
        x = self.x[user_idx, :]
        y = self.y[user_idx]
        if self.batch_size is None:
            return x, y
        else:
            n = x.shape[0]
            idx = torch.randint(low=0, high=n, size=(self.batch_size,))
            return x[idx, :], y[idx]

# %%
class UserProportionDataset(Dataset):
    """Randomly select a proportion of a user's items."""

    def __init__(self, x: np.ndarray, y: np.ndarray, p: float) -> None:
        self.x = torch.tensor(x)
        self.y = torch.tensor(y).unsqueeze(-1)
        self.p = p

    def __len__(self):
        return len(self.x[:, 0].unique())

    def __getitem__(self, user):
        user_idx = self.x[:, 0] == user
        x = self.x[user_idx, :]
        y = self.y[user_idx]
        n_batch = max(1, round(x.shape[0] * self.p))
        idx = torch.randint(low=0, high=x.shape[0], size=(n_batch,))
        return x[idx, :], y[idx]

# %%
class UserRandomSamplingDataset(Dataset):
    def __init__(self, x: np.ndarray, y: np.ndarray, batch_size: int = 10):
        self.x = torch.tensor(x)
        self.y = torch.tensor(y).unsqueeze(-1)
        self.batch_size = batch_size

    def __len__(self):
        # return len(self.x[:, 0].unique())
        return self.x.shape[0]

    def __getitem__(self, idx):
        user = self.x[idx, 0]
        user_idx = self.x[:, 0] == user
        x = self.x[user_idx, :]
        y = self.y[user_idx]
        batch_size = min(x.shape[0], self.batch_size)
        selected_indices = torch.randint(x.shape[0], size=(batch_size,))
        return x[selected_indices, :], y[selected_indices]

# %%
next(iter(train_data_loader))  # note the comma to unpack the tuple
# Out:
# [tensor([[[  89,  492],
#           [  89,  650],
#           [  89,  195],
#           [  89,  215],
#           [  89,  483],
#           [  89, 1191],
#           [  89,  401],
#           [  89,  288],
#           [  89, 1002],
#           [  89,  366]]]),
#  tensor([[[5],
#           [4],
#           [4],
#           [5],
#           [5],
#           [5],
#           [5],
#           [3],
#           [2],
#           [4]]])]
