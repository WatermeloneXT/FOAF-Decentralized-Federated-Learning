# %%
from os import chdir
from pathlib import Path

cwd = Path.cwd()
print(f"CWD: {cwd}")
if cwd.name == "code":
    chdir("..")
print(f"CWD: {Path.cwd()}")
# Out:
# CWD: /Users/haowen/Documents/Decentral RS/fed-learning-main
# CWD: /Users/haowen/Documents/Decentral RS/fed-learning-main

# %%
from src.models.MatrixFactorization import MF, UMF
from src.graphs import random_k_out_graph, create_graph
from src.users import User
from src.training.decentralized import decentralized_train_loop, decentralized_validate_loop, decentralized_train_n_epochs
from src.data_utils import create_batched_dataloaders, create_dataloader

# %%
#Make data sample iterable
from torch.utils.data import Dataset, DataLoader, TensorDataset, Sampler
import torch
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.optim import SGD

from collections import Counter
import networkx as nx
from networkx.generators.classic import empty_graph
from networkx.utils import discrete_sequence, py_random_state, weighted_choice

import seaborn as sns

# %% [markdown]
# ## Parameter Setting

# %%
# lr=0.0061, wd=0.0001, mom=0.5983
model = "umf"
val_loader_type = "rs"
train_loader_type = "rs"
userprop = None
n_factors = 30
sparse = False
batch_size = 10
lr = 0.03871364416669273
weight_decay = 0.14214480688557163
graph_seed = 1
n_epochs = 15

# %% [markdown]
# ## Main

# %%
train_df = pd.read_csv("dataset/ml100k_train.csv")
test_df = pd.read_csv("dataset/ml100k_test.csv")
train_df.head()
# Out:
#    user_id  item_id  rating  rating.1
# 0      207       87       5         5
# 1      675      900       4         4
# 2      373      230       2         2
# 3      377      564       3         3
# 4      725      843       3         3

# %%
n_users = train_df['user_id'].nunique()
n_items = train_df['item_id'].nunique()
print(f"Total User: {n_users}")
print(f"Total Item: {n_items}")
# Out:
# Total User: 943
# Total Item: 1628

# %%
train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=0)
train_data_loader = create_dataloader(
        df=train_df, dl_type=train_loader_type, batch_size=batch_size, p=userprop
    )
val_data_loader = create_dataloader(df=val_df, dl_type=val_loader_type)
test_data_loader = create_dataloader(df=test_df, dl_type=val_loader_type)

# %%
users = {}
for i in tqdm(range(n_users)):
    # model = MF(n_users=n_users, n_items=n_items)
    user_model = UMF(n_items, n_factors = n_factors, sparse = sparse)
    # model = GeneralizedMFOneLayer(n_users=n_users, n_items=n_items)
    #users[i] = User(id=i, model=user_model, optimizer=SGD(user_model.parameters(), lr=lr, weight_decay=weight_decay), model_name = model)
    users[i] = User(
            id=i,
            model=user_model,
            optimizer=SGD(user_model.parameters(), lr=lr, weight_decay=weight_decay, momentum=mom),
            model_name=model,
        )
# Out:
#   0%|          | 0/943 [00:00<?, ?it/s]

# %%
graph = random_k_out_graph(n=n_users, k=2, seed=graph_seed)

# %%
train_losses, val_losses, time_per_epoch = decentralized_train_n_epochs(
        user_models=users,
        train_loader=train_data_loader,
        val_loader=val_data_loader,
        epochs=n_epochs,
        graph=graph,
    )
# Out:
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 1 | Train Loss: 0.6295 | Validation Loss: 1.9248 | Time Elapsed: 73.602618 sec
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 2 | Train Loss: 0.2307 | Validation Loss: 1.8796 | Time Elapsed: 75.539595 sec
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 3 | Train Loss: 0.1519 | Validation Loss: 1.8589 | Time Elapsed: 72.164761 sec
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 4 | Train Loss: 0.0984 | Validation Loss: 1.7984 | Time Elapsed: 72.916536 sec
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 5 | Train Loss: 0.0638 | Validation Loss: 1.7174 | Time Elapsed: 72.935300 sec
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 6 | Train Loss: 0.0428 | Validation Loss: 1.6315 | Time Elapsed: 72.418274 sec
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 7 | Train Loss: 0.0315 | Validation Loss: 1.5930 | Time Elapsed: 71.136274 sec
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 8 | Train Loss: 0.0258 | Validation Loss: 1.5404 | Time Elapsed: 72.364691 sec
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 9 | Train Loss: 0.0229 | Validation Loss: 1.4987 | Time Elapsed: 71.439204 sec
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 10 | Train Loss: 0.0214 | Validation Loss: 1.4546 | Time Elapsed: 72.704075 sec
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 11 | Train Loss: 0.0205 | Validation Loss: 1.4120 | Time Elapsed: 72.646160 sec
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 12 | Train Loss: 0.0200 | Validation Loss: 1.3674 | Time Elapsed: 72.435366 sec
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 13 | Train Loss: 0.0196 | Validation Loss: 1.3264 | Time Elapsed: 72.717934 sec
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 14 | Train Loss: 0.0193 | Validation Loss: 1.3125 | Time Elapsed: 70.891023 sec
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 15 | Train Loss: 0.0191 | Validation Loss: 1.2806 | Time Elapsed: 72.835878 sec
# Total time elapsed: 1091.1502384169999

# %%
test_loss = decentralized_validate_loop(users, test_data_loader)

# %%
test_loss
# Out:
# 1.2914543
