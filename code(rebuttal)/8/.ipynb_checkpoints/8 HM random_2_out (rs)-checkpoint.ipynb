# %% [markdown]
# ## Imports & src definitions
#
# All `src/` logic (UMF, User, create_dataloader, decentralized_train_n_epochs, etc.)
# is inlined here so the notebook is fully self-contained.

# %%
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
from torch.optim import SGD
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import networkx as nx
import time
import math
import copy
import os

torch.manual_seed(0)
np.random.seed(0)

# %%
from os import chdir
from pathlib import Path

new_path = Path("/Users/haowen/Documents/Decentral RS/fed-learning-main")

if new_path.exists():
    os.chdir(new_path)
    print(f"Working directory changed to: {Path.cwd()}")
else:
    print("Path does not exist.")
# Out:
# Working directory changed to: /Users/haowen/Documents/Decentral RS/fed-learning-main

# %%
from src.models.MatrixFactorization import MF, UMF
from src.graphs import random_k_out_graph, create_graph
from src.users import User
from src.training.decentralized import (decentralized_train_n_epochs,
                                        decentralized_validate_loop)
from src.data_utils import create_batched_dataloaders, create_dataloader

# %%
#Make data sample iterable
from torch.utils.data import Dataset, DataLoader, TensorDataset, Sampler
import torch
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.optim import SGD

from collections import Counter
import networkx as nx
from networkx.generators.classic import empty_graph
from networkx.utils import discrete_sequence, py_random_state, weighted_choice

import seaborn as sns
from sklearn.utils import shuffle

# %% [markdown]
# ## Parameter Setting

# %%
model_type       = "umf"
val_loader_type  = "rs"
train_loader_type = "rs"
userprop         = None
n_factors        = 30
sparse           = False
batch_size       = 10
lr               = 0.03871364416669273
weight_decay     = 0.14214480688557163
mom              = 0.001
graph_seed       = 1
n_epochs         = 50
SEED             = 42

# %% [markdown]
# ## Main

# %%
# ── Load sampled H&M dataset from cache ───────────────────────────────────────
# Set these to match what was used when sampling was run.
TARGET_USERS           = 1000
MIN_INTERACTIONS = 20
SAMPLED_DATA_DIR       = r"/Users/haowen/Documents/Decentral RS/rebuttal/code/8"

#cache_tag  = f"u{TARGET_USERS}_m{MIN_INTERACTIONS}_t25_v20_s42"
train_path = os.path.join(SAMPLED_DATA_DIR, f"hm_subset_train.csv")
val_path   = os.path.join(SAMPLED_DATA_DIR, f"hm_val_df.csv")
test_path  = os.path.join(SAMPLED_DATA_DIR, f"hm_subset_test.csv")
#meta_path  = os.path.join(SAMPLED_DATA_DIR, f"meta_{cache_tag}.csv")

assert all(os.path.exists(p) for p in [train_path, val_path, test_path]), (
    f"Cached files not found in '{SAMPLED_DATA_DIR}/'.\n"
    "Run the hm_foaf_experiment_sampled.ipynb preprocessing section first "
    "to generate the cache."
)

train_df = pd.read_csv(train_path)
val_df   = pd.read_csv(val_path)
test_df  = pd.read_csv(test_path)
#meta_df  = pd.read_csv(meta_path)

n_users = train_df['user_id'].nunique()
n_items = train_df['item_id'].nunique()

#print(f"Loaded from cache: {cache_tag}")
print(f"Total User: {n_users}")
print(f"Total Item: {n_items}")
train_df.head()
# Out:
# Total User: 1200
# Total Item: 2105
#    user_id  item_id  bought
# 0      113      691       1
# 1      870      310       1
# 2      265      601       2
# 3      611        6       1
# 4      319      101       2

# %%
train_df.head()
# Out:
#    user_id  item_id  bought
# 0      113      691       1
# 1      870      310       1
# 2      265      601       2
# 3      611        6       1
# 4      319      101       2

# %%
val_df.head()
val_df = val_df.rename(columns={'customer_id': 'age', 'B': 'score'})
# Out:
#    customer_id  product_code  bought
# 0            0          1389       1
# 1            0          3240       1
# 2            0          2767       1
# 3            0           846       1
# 4            0           411       1

# %%
test_df.head()
# Out:
#    user_id  item_id  bought
# 0      454      973       1
# 1     1034     1677       1
# 2      394     1206       1
# 3      579      225       4
# 4      938     1298       1

# %%
# ── DataLoaders ───────────────────────────────────────────────────────────────
train_data_loader = create_dataloader(
    df=train_df, dl_type=train_loader_type, batch_size=batch_size, p=userprop
)
val_data_loader  = create_dataloader(df=val_df,  dl_type=val_loader_type)
test_data_loader = create_dataloader(df=test_df, dl_type=val_loader_type)

print(f"Train batches: {len(train_data_loader)} | "
      f"Val batches: {len(val_data_loader)} | "
      f"Test batches: {len(test_data_loader)}")
# Out:
# Train batches: 48442 | Val batches: 30253 | Test batches: 12111

# %%
# ── Initialise one UMF model per user ─────────────────────────────────────────
users = {}
for i in tqdm(range(n_users)):
    user_model = UMF(n_items, n_factors=n_factors, sparse=sparse)
    users[i] = User(
        id=i,
        model=user_model,
        optimizer=SGD(user_model.parameters(),
                      lr=lr, weight_decay=weight_decay, momentum=mom),
        model_name=model_type,
    )
# Out:
#   0%|          | 0/1200 [00:00<?, ?it/s]

# %%
# ── Build graph ───────────────────────────────────────────────────────────────
graph = random_k_out_graph(n=n_users, k=2, seed=graph_seed)

# %%
# ── Train ─────────────────────────────────────────────────────────────────────
torch.manual_seed(0)
train_losses, val_losses, time_per_epoch, commutes = decentralized_train_n_epochs(
    user_models=users,
    train_loader=train_data_loader,
    val_loader=val_data_loader,
    epochs=n_epochs,
    graph=graph,
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 3
#       1 # ── Train ─────────────────────────────────────────────────────────────────────
#       2 torch.manual_seed(0)
# ----> 3 train_losses, val_losses, time_per_epoch, commutes = decentralized_train_n_epochs(
#       4     user_models=users,
#       5     train_loader=train_data_loader,
#       6     val_loader=val_data_loader,
#       7     epochs=n_epochs,
#       8     graph=graph,
#       9 )
#
# File ~/Documents/Decentral RS/fed-learning-main/src/training/decentralized.py:193, in decentralized_train_n_epochs(user_models, train_loader, val_loader, epochs, graph, break_gate)
#     191 train_commutes_cost = []
#     192 val_losses = []
# --> 193 val_loss = decentralized_validate_loop(user_models, val_loader)
#     194 mlflow.log_metrics({"Validation RMSE": val_loss}, step=0)
#     195 val_losses.append(val_loss)
#
# File ~/Documents/Decentral RS/fed-learning-main/src/training/decentralized.py:60, in decentralized_validate_loop(user_models, val_loader)
#      58     continue
#      59 user_id = int(inputs[0, 0])
# ---> 60 score = user_models[user_id].model(inputs[:, 0], inputs[:, 1])
#      62 user_rmse = np.sqrt(loss_fn(score, target.float()).detach().numpy())
#      63 # sum_loss = loss_fn(score, target.float()).detach().numpy()
#      64 # mean_loss = sum_loss / n_obs
#      65 #
#      66 # total_sum_loss += sum_loss
#      67 # total_obs += n_obs
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/Documents/Decentral RS/fed-learning-main/src/models/MatrixFactorization.py:55, in UMF.forward(self, users, items)
#      53 def forward(self, users, items):
#      54     user = users.new_zeros(users.shape[0])  # sa
# ---> 55     preds = (self.user_factors(user) * self.item_factors(items)).sum(dim=1, keepdims=True)
#      56     preds += self.user_bias(user)
#      57     preds += self.item_bias(items)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/sparse.py:190, in Embedding.forward(self, input)
#     189 def forward(self, input: Tensor) -> Tensor:
# --> 190     return F.embedding(
#     191         input,
#     192         self.weight,
#     193         self.padding_idx,
#     194         self.max_norm,
#     195         self.norm_type,
#     196         self.scale_grad_by_freq,
#     197         self.sparse,
#     198     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/functional.py:2551, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2545     # Note [embedding_renorm set_grad_enabled]
#    2546     # XXX: equivalent to
#    2547     # with torch.no_grad():
#    2548     #   torch.embedding_renorm_
#    2549     # remove once script supports set_grad_enabled
#    2550     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2551 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# IndexError: index out of range in self

# %%
# ── Test evaluation ───────────────────────────────────────────────────────────
test_loss = decentralized_validate_loop(users, test_data_loader)

# %%
test_loss
