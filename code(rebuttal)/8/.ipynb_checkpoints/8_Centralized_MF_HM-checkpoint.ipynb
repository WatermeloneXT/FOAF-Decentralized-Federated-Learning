# %%
import os
import numpy as np
import pandas as pd
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
from torch.optim import SGD
from tqdm.auto import tqdm
from sklearn.model_selection import train_test_split

# %%
SAMPLED_DATA_DIR = r"/Users/haowen/Documents/Decentral RS/rebuttal/code/8"

train_path = os.path.join(SAMPLED_DATA_DIR, "hm_subset_train.csv")
test_path  = os.path.join(SAMPLED_DATA_DIR, "hm_subset_test.csv")

train_df = pd.read_csv(train_path)
test_df  = pd.read_csv(test_path)

# Cast IDs to str to handle mixed-type H&M IDs consistently
for df in [train_df, test_df]:
    df["user_id"] = df["user_id"].astype(str)
    df["item_id"] = df["item_id"].astype(str)

# Build contiguous 0-based encoders fitted on train only
user_enc = {u: i for i, u in enumerate(sorted(train_df["user_id"].unique()))}
item_enc = {v: i for i, v in enumerate(sorted(train_df["item_id"].unique()))}

def remap(df, user_enc, item_enc, drop_unknown=False):
    df = df.copy()
    if drop_unknown:
        df = df[df["user_id"].isin(user_enc) & df["item_id"].isin(item_enc)]
    df["user_id"] = df["user_id"].map(user_enc)
    df["item_id"] = df["item_id"].map(item_enc)
    return df.dropna(subset=["user_id", "item_id"]).astype({"user_id": int, "item_id": int})

train_df = remap(train_df, user_enc, item_enc)
test_df  = remap(test_df,  user_enc, item_enc, drop_unknown=True)

train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=0)

n_users = len(user_enc)
n_items = len(item_enc)
print(f"Total Users : {n_users}")
print(f"Total Items : {n_items}")
train_df.head()
# Out:
# Cache tag: u1000_m30_s42

# %%
# Data loaded and remapped above.
print(f"Train rows : {len(train_df)}")
print(f"Val rows   : {len(val_df)}")
print(f"Test rows  : {len(test_df)}")
print(f"Rating col : {train_df.columns[2]}  "
      f"range [{train_df.iloc[:,2].min()}, {train_df.iloc[:,2].max()}]")
# Out:
# Loaded from cache: u1000_m30_s42
# Total Users: 820
# Total Items: 7290
#    customer_id  product_code  bought
# 0            1            83       1
# 1          214           248       2
# 2           39          1466       1
# 3          406          2880       1
# 4          700          2293       1

# %%
# ── Dataset & DataLoader (self-contained, no src dependency) ─────────────────
class RatingDataset(Dataset):
    """Wraps a DataFrame with columns [user_id, item_id, rating].
    Column positions 0,1,2 are used so any column names work.
    """
    def __init__(self, df):
        arr = df.iloc[:, :3].values
        self.users   = torch.tensor(arr[:, 0], dtype=torch.long)
        self.items   = torch.tensor(arr[:, 1], dtype=torch.long)
        self.ratings = torch.tensor(arr[:, 2], dtype=torch.float32)

    def __len__(self):  return len(self.ratings)

    def __getitem__(self, idx):
        return (torch.stack([self.users[idx], self.items[idx]], dim=0),
                self.ratings[idx])


def make_loader(df, batch_size, shuffle=True):
    return DataLoader(RatingDataset(df), batch_size=batch_size, shuffle=shuffle)

# %%
# ── Matrix Factorisation model ────────────────────────────────────────────────
class MatrixFactorization(nn.Module):
    def __init__(self, num_users, num_items, embedding_dim=32):
        super().__init__()
        self.user_emb  = nn.Embedding(num_users, embedding_dim)
        self.item_emb  = nn.Embedding(num_items, embedding_dim)
        self.user_bias = nn.Embedding(num_users, 1)
        self.item_bias = nn.Embedding(num_items, 1)
        self.global_bias = nn.Parameter(torch.tensor([0.0]))

        nn.init.normal_(self.user_emb.weight,  std=0.1)
        nn.init.normal_(self.item_emb.weight,  std=0.1)
        nn.init.zeros_(self.user_bias.weight)
        nn.init.zeros_(self.item_bias.weight)

    def forward(self, user_ids, item_ids):
        u   = self.user_emb(user_ids)
        v   = self.item_emb(item_ids)
        dot = (u * v).sum(1, keepdim=True)
        return (dot + self.user_bias(user_ids)
                    + self.item_bias(item_ids)
                    + self.global_bias).squeeze()

# %%
# ── Training & validation loops ──────────────────────────────────────────────
def train_loop(model, loader, optimizer, device='cpu'):
    loss_fn = nn.MSELoss(reduction='mean')
    model.train()
    total_loss, total_n = 0.0, 0
    for inputs, target in tqdm(loader, leave=False):
        inputs, target = inputs.to(device), target.to(device)
        optimizer.zero_grad()
        pred = model(inputs[:, 0], inputs[:, 1])
        loss = loss_fn(pred, target)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * len(target)
        total_n    += len(target)
    return np.sqrt(total_loss / total_n)   # train RMSE


def validate_loop(model, loader, device='cpu'):
    loss_fn = nn.MSELoss(reduction='sum')
    model.eval()
    total_loss, total_n = 0.0, 0
    with torch.no_grad():
        for inputs, target in loader:
            inputs, target = inputs.to(device), target.to(device)
            pred        = model(inputs[:, 0], inputs[:, 1])
            total_loss += loss_fn(pred, target).item()
            total_n    += len(target)
    # FIX: return RMSE directly (original double-sqrt bug removed)
    return np.sqrt(total_loss / total_n)   # val RMSE

# %%
# ── Hyperparameters ───────────────────────────────────────────────────────────
batch_size   = 64
n_factors    = 30
lr           = 1e-2
weight_decay = 2e-3
momentum     = 0.1
n_epochs     = 50
patience     = 5
device       = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"device: {device}")
# Out:
# device: cpu

# %% [markdown]
# ## Parameter Tuning — Grid Search
#
# Grid over `n_factors`, `lr`, and `weight_decay`.
# Each combo trains for up to 20 epochs with patience-3 on val RMSE.
# Writes `n_factors`, `lr`, `weight_decay` for the full training run.

# %%
from itertools import product as iproduct

N_FACTORS_GRID   = [16, 32, 64]
LR_GRID          = [1e-3, 1e-2, 5e-2]
WEIGHT_DECAY_GRID= [1e-4, 1e-3, 1e-2]
TUNE_EPOCHS      = 20
TUNE_PAT         = 3
TUNE_BATCH       = 256   # larger batch for speed during tuning

param_grid = list(iproduct(N_FACTORS_GRID, LR_GRID, WEIGHT_DECAY_GRID))
print(f"Grid search: {len(param_grid)} combinations x up to {TUNE_EPOCHS} epochs")
print(f"{'#':>3}  {'factors':>8}  {'lr':>8}  {'wd':>8}  {'best val RMSE':>14}")
print("-" * 48)

# Fixed during tuning
_momentum   = 0.1
_tune_dl    = make_loader(train_df, batch_size=TUNE_BATCH, shuffle=True)
_tune_val   = make_loader(val_df,   batch_size=512,        shuffle=False)

grid_results = []

for _k, (_nf, _lr, _wd) in enumerate(param_grid, 1):
    torch.manual_seed(0)
    _model = MatrixFactorization(n_users, n_items, embedding_dim=_nf).to(device)
    _opt   = SGD(_model.parameters(), lr=_lr, weight_decay=_wd, momentum=_momentum)
    _es    = EarlyStopper(patience=TUNE_PAT)
    _best_val = float('inf')

    for _ep in range(TUNE_EPOCHS):
        train_loop(_model, _tune_dl, _opt, device)
        _v = validate_loop(_model, _tune_val, device)
        if _v < _best_val:
            _best_val = _v
        if _es.step(_v):
            break

    grid_results.append((_best_val, _nf, _lr, _wd))
    _marker = ' <--' if _best_val == min(r[0] for r in grid_results) else ''
    print(f"{_k:>3}  {_nf:>8d}  {_lr:>8.4f}  {_wd:>8.5f}  {_best_val:>14.4f}{_marker}")

_best = min(grid_results, key=lambda x: x[0])
best_val_rmse_tune, best_nf, best_lr, best_wd = _best
print(f"\nBest val RMSE  : {best_val_rmse_tune:.4f}")
print(f"  n_factors      = {best_nf}")
print(f"  lr             = {best_lr}")
print(f"  weight_decay   = {best_wd}")
n_factors    = best_nf
lr           = best_lr
weight_decay = best_wd
print("\nHyperparameters updated. Run the training cell.")

# %%
# ── DataLoaders ───────────────────────────────────────────────────────────────
# Centralized: pool all users' data into a single loader
train_dl = make_loader(train_df, batch_size=batch_size, shuffle=True)
val_dl   = make_loader(val_df,   batch_size=256,        shuffle=False)
test_dl  = make_loader(test_df,  batch_size=256,        shuffle=False)

print(f"Train batches: {len(train_dl)} | Val batches: {len(val_dl)} | Test batches: {len(test_dl)}")
# Out:
# Train batches: 565 | Val batches: 36 | Test batches: 54

# %%
# ── Model, optimiser, early stopping ─────────────────────────────────────────
# Fall back to defaults if grid search was skipped
try: n_factors
except NameError: n_factors = 30
try: lr
except NameError: lr = 1e-2
try: weight_decay
except NameError: weight_decay = 2e-3

model = MatrixFactorization(n_users, n_items, embedding_dim=n_factors).to(device)
optimizer = SGD(model.parameters(), lr=lr, weight_decay=weight_decay, momentum=momentum)

early_stopper = EarlyStopper(patience=patience)

# %%
# ── Training ──────────────────────────────────────────────────────────────────
train_losses, val_losses = [], []

for epoch in range(1, n_epochs + 1):
    tr_rmse  = train_loop(model, train_dl, optimizer, device)
    val_rmse = validate_loop(model, val_dl, device)
    train_losses.append(tr_rmse)
    # FIX: val_rmse is already RMSE — do NOT take sqrt again
    val_losses.append(val_rmse)
    print(f"Epoch {epoch:3d} | Train RMSE: {tr_rmse:.4f} | Val RMSE: {val_rmse:.4f}")
    if early_stopper.step(val_rmse):
        print("Early stopping.")
        break
# Out:
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch   1 | Train RMSE: 0.9858 | Val RMSE: 0.8883
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch   2 | Train RMSE: 0.9401 | Val RMSE: 0.8862
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch   3 | Train RMSE: 0.9372 | Val RMSE: 0.8843
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch   4 | Train RMSE: 0.9346 | Val RMSE: 0.8825
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch   5 | Train RMSE: 0.9321 | Val RMSE: 0.8808
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch   6 | Train RMSE: 0.9297 | Val RMSE: 0.8792
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch   7 | Train RMSE: 0.9274 | Val RMSE: 0.8779
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch   8 | Train RMSE: 0.9252 | Val RMSE: 0.8763
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch   9 | Train RMSE: 0.9231 | Val RMSE: 0.8752
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  10 | Train RMSE: 0.9212 | Val RMSE: 0.8738
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  11 | Train RMSE: 0.9194 | Val RMSE: 0.8729
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  12 | Train RMSE: 0.9176 | Val RMSE: 0.8717
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  13 | Train RMSE: 0.9159 | Val RMSE: 0.8707
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  14 | Train RMSE: 0.9143 | Val RMSE: 0.8695
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  15 | Train RMSE: 0.9128 | Val RMSE: 0.8686
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  16 | Train RMSE: 0.9113 | Val RMSE: 0.8676
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  17 | Train RMSE: 0.9100 | Val RMSE: 0.8669
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  18 | Train RMSE: 0.9086 | Val RMSE: 0.8661
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  19 | Train RMSE: 0.9074 | Val RMSE: 0.8657
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  20 | Train RMSE: 0.9061 | Val RMSE: 0.8647
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  21 | Train RMSE: 0.9050 | Val RMSE: 0.8642
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  22 | Train RMSE: 0.9038 | Val RMSE: 0.8635
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  23 | Train RMSE: 0.9028 | Val RMSE: 0.8628
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  24 | Train RMSE: 0.9017 | Val RMSE: 0.8621
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  25 | Train RMSE: 0.9007 | Val RMSE: 0.8627
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  26 | Train RMSE: 0.8999 | Val RMSE: 0.8612
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  27 | Train RMSE: 0.8990 | Val RMSE: 0.8610
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  28 | Train RMSE: 0.8981 | Val RMSE: 0.8603
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  29 | Train RMSE: 0.8972 | Val RMSE: 0.8597
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  30 | Train RMSE: 0.8964 | Val RMSE: 0.8598
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  31 | Train RMSE: 0.8956 | Val RMSE: 0.8599
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  32 | Train RMSE: 0.8949 | Val RMSE: 0.8584
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  33 | Train RMSE: 0.8942 | Val RMSE: 0.8597
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  34 | Train RMSE: 0.8937 | Val RMSE: 0.8578
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  35 | Train RMSE: 0.8929 | Val RMSE: 0.8574
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  36 | Train RMSE: 0.8923 | Val RMSE: 0.8571
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  37 | Train RMSE: 0.8917 | Val RMSE: 0.8569
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  38 | Train RMSE: 0.8911 | Val RMSE: 0.8565
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  39 | Train RMSE: 0.8905 | Val RMSE: 0.8562
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  40 | Train RMSE: 0.8900 | Val RMSE: 0.8559
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  41 | Train RMSE: 0.8895 | Val RMSE: 0.8558
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  42 | Train RMSE: 0.8890 | Val RMSE: 0.8554
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  43 | Train RMSE: 0.8885 | Val RMSE: 0.8554
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  44 | Train RMSE: 0.8880 | Val RMSE: 0.8553
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  45 | Train RMSE: 0.8876 | Val RMSE: 0.8553
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  46 | Train RMSE: 0.8871 | Val RMSE: 0.8550
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  47 | Train RMSE: 0.8868 | Val RMSE: 0.8545
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  48 | Train RMSE: 0.8863 | Val RMSE: 0.8541
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  49 | Train RMSE: 0.8859 | Val RMSE: 0.8539
#   0%|          | 0/565 [00:00<?, ?it/s]
# Epoch  50 | Train RMSE: 0.8856 | Val RMSE: 0.8537

# %%
# ── Test evaluation ───────────────────────────────────────────────────────────
test_rmse = validate_loop(model, test_dl, device)
print(f"Test RMSE: {test_rmse:.4f}")
# Out:
# Test RMSE: 0.9980

# %%
# ── Save per-epoch log ───────────────────────────────────────────────────────
import pandas as pd
log_df = pd.DataFrame({
    "epoch":      list(range(1, len(val_losses) + 1)),
    "train_rmse": train_losses,
    "val_rmse":   val_losses,
})
log_df.to_csv("cmf_hm.csv", index=False)
print(f"Saved cmf_hm.csv  ({len(log_df)} epochs)")
log_df
# Out:
# Saved cmf_hm.csv  (50 epochs)
#     epoch  train_rmse  val_rmse
# 0       1    0.985804  0.888332
# 1       2    0.940079  0.886182
# 2       3    0.937197  0.884266
# 3       4    0.934566  0.882499
# 4       5    0.932062  0.880812
# 5       6    0.929661  0.879212
# 6       7    0.927379  0.877889
# 7       8    0.925241  0.876277
# 8       9    0.923146  0.875247
# 9      10    0.921232  0.873753
# 10     11    0.919364  0.872895
# 11     12    0.917615  0.871730
# 12     13    0.915947  0.870651
# 13     14    0.914340  0.869517
# 14     15    0.912820  0.868616
# 15     16    0.911312  0.867629
# 16     17    0.909960  0.866940
# 17     18    0.908594  0.866052
# 18     19    0.907373  0.865667
# 19     20    0.906109  0.864654
# 20     21    0.904960  0.864177
# 21     22    0.903846  0.863498
# 22     23    0.902801  0.862848
# 23     24    0.901738  0.862150
# 24     25    0.900731  0.862664
# 25     26    0.899874  0.861212
# 26     27    0.898963  0.861009
# 27     28    0.898098  0.860335
# 28     29    0.897242  0.859709
# 29     30    0.896442  0.859803
# 30     31    0.895639  0.859937
# 31     32    0.894915  0.858449
# 32     33    0.894205  0.859704
# 33     34    0.893659  0.857783
# 34     35    0.892926  0.857385
# 35     36    0.892287  0.857077
# 36     37    0.891696  0.856887
# 37     38    0.891056  0.856497
# 38     39    0.890531  0.856163
# 39     40    0.889997  0.855891
# 40     41    0.889508  0.855792
# 41     42    0.888986  0.855397
# 42     43    0.888490  0.855362
# 43     44    0.888046  0.855256
# 44     45    0.887579  0.855339
# 45     46    0.887088  0.855018
# 46     47    0.886817  0.854481
# 47     48    0.886337  0.854122
# 48     49    0.885943  0.853910
# 49     50    0.885587  0.853715
